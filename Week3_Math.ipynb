# %%
name:Adarsha Pantha
L4CG4
# Out:
#   File "<ipython-input-1-01e6a8bd21b3>", line 1
#     name:Adarsha Pantha
#                  ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[1,4,9,16]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[1,4,9,16]
plt.xlim(0,50)
plt.ylim(0,50)
plt.grid()
plt.show()

# %%
#example 2
import matplotlib.pyplot as plt
x=[2, 3, 4, 5]
plt.plot(x)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[2, 3, 4, 5]
y=[3,4,5,6]
plt.plot(x, y, marker='o', color='red', linewidth=5)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('The Graph')
plt.show()

# %%
#example 4
import matplotlib.pyplot as plt
x=[2, 3, 4, 5]
y=[3, 4, 5, 6]
plt.plot(x, y, marker='o', color='blue',label='line 1', linewidth=3)
plt.plot(x, marker='+', color='green',label='line 2', linewidth=2)
plt.title('Example 4')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.grid()
plt.show()

# %%
#task 2
# The following table shows the different vehicles and the distance covered by them in the span
# of 5 days. Display the following table in line plot.
# a. Plot “days” in X- axis and “distance covered” in Y- axis.
# b. Title of the table “bike details in Plot”

import matplotlib.pyplot as plt

table_data = {
    "ENFIELD": [50, 40, 70, 80, 20],
    "HONDA": [80, 20, 20,50, 60],
    "YAMAHA": [70,20,60,40,60],
     "KTM": [40,20,30,70,60]
}

days = list(range(1, 6))
distances = {vehicle: table_data[vehicle] for vehicle in table_data}

for vehicle, distance in distances.items():
    plt.plot(days, distance, marker='o', label=vehicle)

plt.xlabel('Days')
plt.ylabel('Distance Covered')
plt.title('Bike details in Plot')

plt.legend()

plt.show()

# %%
#Example 5
import matplotlib.pyplot as plt

def function(x):
    result = 3*x + 2
    return result

xCoord = []
yCoord = []

for i in range(0, 10):
    xCoord.append(i)
    yCoord.append(function(i))

plt.plot(xCoord, yCoord, marker='x', color='red')
plt.title('Example 5')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid()
plt.show()

# %%
#exercise 1

import matplotlib.pyplot as plt

x = range(1, 5)

y = [i for i in x]

plt.plot(x, y)

plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = x')

plt.show()

# %%
#exercise3

import matplotlib.pyplot as plt
import math

x1 = [-2 + i * 4/19 for i in range(20)]
x2 = [-3 + i * 6/19 for i in range(20)]
x3 = [-10 + i * 20/19 for i in range(20)]

def function1(x):
    return 5*x**3 + 2*x - 1

def function2(x):
    return -2*x**3 + x**2 + 100

def function3(x):
    return 2*math.pi*x + 20

y1 = [function1(x) for x in x1]
y2 = [function2(x) for x in x2]
y3 = [function3(x) for x in x3]

plt.plot(x1, y1, color='blue', label='f(x) = 5x^3 + 2x - 1')
plt.plot(x2, y2, color='red', label='f(x) = -2x^3 + x^2 + 100')
plt.plot(x3, y3, color='green', label='f(x) = 2πx + 20')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of Three Functions', fontsize=16, fontweight='bold')

plt.legend()
plt.grid()
plt.show()

# %%
#example 5

import matplotlib.pyplot as plt

x = [1, 2, 3]
y = [4, 5, 6]

plt.subplot(2, 2, 1)
plt.plot(x, y, marker='*', color='red')

plt.subplot(2, 2, 2)
plt.plot(x, y, marker='x', color='green')

plt.subplot(2, 2, 3)
plt.plot(x, y, marker='^', color='blue')

plt.subplot(2, 2, 4)
plt.plot(x, y, marker='+', color='yellow')

plt.show()

# %%
#exercise4

import matplotlib.pyplot as plt
import math

x1 = [2 + i * 4/19 for i in range(20)]
x2 = [3 + i * 6/19 for i in range(20)]
x3 = [10 + i * 20/19 for i in range(20)]

def function1(x):
    return 5*x**3 + 2*x - 1

def function2(x):
    return -2*x**3 + x**2 + 100

def function3(x):
    return 2*(22/7)*x + 20

y1 = [function1(x) for x in x1]
y2 = [function2(x) for x in x2]
y3 = [function3(x) for x in x3]

plt.figure(figsize=(15, 6))

plt.subplot(1, 3, 1)
plt.plot(x1, y1, label='f(x) = 5x^3 + 2x - 1', color='blue')
plt.title('Function 1')
plt.legend()

plt.subplot(1, 3, 2)
plt.plot(x2, y2, label='f(x) = -2x^3 + x^2 + 100', color='red')
plt.title('Function 2')
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(x3, y3, label='f(x) = 2πx + 20', color='green')
plt.title('Function 3')
plt.legend()

plt.suptitle('Plots of Three Functions', fontsize=16, fontweight='bold')

plt.show()

# %%
#example-6
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

fig, ax = plt.subplots(figsize=(8, 6))

ax.plot(x, y, linestyle='-', linewidth=2, color='blue', marker='o', markersize=8,
        markerfacecolor='red', markeredgewidth=2, markeredgecolor='green', alpha=0.7, label='Line 1')

ax.set_xlim(0, 6)
ax.set_ylim(0, 12)

ax.grid(linestyle='--', linewidth=0.5, color='gray', alpha=0.5)

ax.set_title('Line Chart with Various Styles', fontsize=16, fontweight='bold', color='purple')
ax.set_xlabel('X-axis', fontsize=12, fontweight='bold', color='blue')
ax.set_ylabel('Y-axis', fontsize=12, fontweight='bold', color='green')

ax.legend(loc='upper left', fontsize=10, frameon=True, fancybox=True, shadow=True, facecolor='lightgray')

ax.text(3, 8, 'Annotation', fontsize=10, fontstyle='italic', color='red')

ax.annotate('Arrow', xy=(2, 4), xytext=(3, 6),
            arrowprops=dict(facecolor='orange', shrink=0.05))

plt.show()

# %%
import matplotlib.pyplot as plt

days = ['DAY 1', 'DAY 2', 'DAY 3', 'DAY 4', 'DAY 5']
enfield = [50, 40, 70, 80, 20]
honda = [80, 20, 20, 50, 60]
yahama = [70, 20, 60, 40, 60]
ktm = [40, 20, 30, 70, 60]

plt.subplot(2, 2, 1)
plt.plot(days, enfield, marker='o', color='red')
plt.title('ENFIELD')
plt.xlabel('Days')
plt.ylabel('Distance Covered (km)')

plt.subplot(2, 2, 2)
plt.plot(days, honda, marker='x', color='green')
plt.title('HONDA')
plt.xlabel('Days')
plt.ylabel('Distance Covered (km)')

plt.subplot(2, 2, 3)
plt.plot(days, yahama, marker='^', color='blue')
plt.title('YAHAMA')
plt.xlabel('Days')
plt.ylabel('Distance Covered (km)')

plt.subplot(2, 2, 4)
plt.plot(days, ktm, marker='+', color='yellow')
plt.title('KTM')
plt.xlabel('Days')
plt.ylabel('Distance Covered (km)')

plt.tight_layout()

plt.show()
